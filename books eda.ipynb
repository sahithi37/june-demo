# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("book1-100k.csv")
data
# Out:
#           Id                                               Name RatingDist1  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...      1:9896
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 2          3  Harry Potter and the Sorcerer's Stone (Harry P...    1:108202
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# ...      ...                                                ...         ...
# 58287  99992  The Best American Science and Nature Writing 2000         1:2
# 58288  99993  The Best American Science and Nature Writing 2002         1:0
# 58289  99996  Hunting and Home in the Southern Heartland: Th...         1:0
# 58290  99997             The Best American Science Writing 2004         1:2
# 58291  99999                 The Best American Sex Writing 2004         1:1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58292 entries, 0 to 58291
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               58292 non-null  int64
#  1   Name             58292 non-null  object
#  2   RatingDist1      58292 non-null  object
#  3   pagesNumber      58292 non-null  int64
#  4   RatingDist4      58292 non-null  object
#  5   RatingDistTotal  58292 non-null  object
#  6   PublishMonth     58292 non-null  int64
#  7   PublishDay       58292 non-null  int64
#  8   Publisher        57798 non-null  object
#  9   CountsOfReview   58292 non-null  int64
#  10  PublishYear      58292 non-null  int64
#  11  Language         20294 non-null  object
#  12  Authors          58292 non-null  object
#  13  Rating           58292 non-null  float64
#  14  RatingDist2      58292 non-null  object
#  15  RatingDist5      58292 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Id                     0
# Name                   0
# RatingDist1            0
# pagesNumber            0
# RatingDist4            0
# RatingDistTotal        0
# PublishMonth           0
# PublishDay             0
# Publisher            494
# CountsOfReview         0
# PublishYear            0
# Language           37998
# Authors                0
# Rating                 0
# RatingDist2            0
# RatingDist5            0
# ISBN                 546
# RatingDist3            0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data
# Out:
#           Id                                               Name RatingDist1  \
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 6          8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7          9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# ...      ...                                                ...         ...
# 58260  99958  Thomas Paine and the Promise of America (Oxfor...         1:6
# 58262  99962                    Common Sense and Other Writings       1:207
# 58265  99965               Faith of My Fathers: A Family Memoir        1:52
# 58280  99985                  Science Fiction: The Best of 2001         1:1
# 58281  99986                        Nebula Awards Showcase 2001         1:0
#
# ...

# %%
data['Name'].values
# Out:
# array(['Harry Potter and the Order of the Phoenix (Harry Potter, #5)',
#        'Harry Potter and the Chamber of Secrets (Harry Potter, #2)',
#        'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)', ...,
#        'Faith of My Fathers: A Family Memoir',
#        'Science Fiction: The Best of 2001', 'Nebula Awards Showcase 2001'],
#       dtype=object)

# %%
data['Publisher'].values
# Out:
# array(['Scholastic Inc.', 'Scholastic', 'Scholastic Inc.', ...,
#        'William Morrow Paperbacks', 'Fantastic Audio', 'Mariner Books'],
#       dtype=object)

# %%
data.dtypes
# Out:
# Id                   int64
# Name                object
# RatingDist1         object
# pagesNumber          int64
# RatingDist4         object
# RatingDistTotal     object
# PublishMonth         int64
# PublishDay           int64
# Publisher           object
# CountsOfReview       int64
# PublishYear          int64
# Language            object
# Authors             object
# Rating             float64
# RatingDist2         object
# RatingDist5         object
# ISBN                object
# RatingDist3         object
# dtype: object

# %%
data1=(data[data.Rating>=3.5])

# %%
data1
# Out:
#           Id                                               Name RatingDist1  \
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 6          8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7          9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# ...      ...                                                ...         ...
# 58258  99956                            The Thomas Paine Reader         1:2
# 58260  99958  Thomas Paine and the Promise of America (Oxfor...         1:6
# 58262  99962                    Common Sense and Other Writings       1:207
# 58265  99965               Faith of My Fathers: A Family Memoir        1:52
# 58281  99986                        Nebula Awards Showcase 2001         1:0
#
# ...

# %%
data2 = data[data['Rating']>=3.5]

# %%
data2
# Out:
#           Id                                               Name RatingDist1  \
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 6          8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7          9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# ...      ...                                                ...         ...
# 58258  99956                            The Thomas Paine Reader         1:2
# 58260  99958  Thomas Paine and the Promise of America (Oxfor...         1:6
# 58262  99962                    Common Sense and Other Writings       1:207
# 58265  99965               Faith of My Fathers: A Family Memoir        1:52
# 58281  99986                        Nebula Awards Showcase 2001         1:0
#
# ...

# %%
data3 =data[data.Rating>=3.5]

# %%
data3
# Out:
#           Id                                               Name RatingDist1  \
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 6          8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7          9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# ...      ...                                                ...         ...
# 58258  99956                            The Thomas Paine Reader         1:2
# 58260  99958  Thomas Paine and the Promise of America (Oxfor...         1:6
# 58262  99962                    Common Sense and Other Writings       1:207
# 58265  99965               Faith of My Fathers: A Family Memoir        1:52
# 58281  99986                        Nebula Awards Showcase 2001         1:0
#
# ...

# %%
data4 = data[data.PublishYear==2005]

# %%
data4
# Out:
#           Id                                               Name RatingDist1  \
# 7          9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# 8         10       Harry Potter Collection (Harry Potter, #1-6)       1:257
# 9         12  The Ultimate Hitchhiker's Guide: Five Complete...      1:3443
# 28        45  Agile Web Development with Rails: A Pragmatic ...        1:56
# 34        55     Hatchet Jobs: Writings on Contemporary Fiction        1:10
# ...      ...                                                ...         ...
# 57989  99472            Shakespeare's Counselor (Lily Bard, #5)        1:56
# 58073  99661                   Rain and Other South Sea Stories        1:10
# 58125  99756                                         Love Story      1:2019
# 58235  99919  The Strategy and Tactics of Pricing: A Guide t...         1:9
# 58262  99962                    Common Sense and Other Writings       1:207
#
# ...

# %%
data5 = pd.DataFrame([data4.Authors,data4.Rating]).transpose()

# %%
d = data5.groupby(['Authors'])['Rating'].mean()

# %%
d
# Out:
# Authors
# A.J. Jacobs              3.76
# A.S. Byatt               3.80
# Aaron Elkins             3.79
# Abraham Lincoln          4.14
# Adam Ginsberg            3.48
#                          ...
# Yuki Shimizu             3.93
# Yukito Kishiro           4.31
# Zilpha Keatley Snyder    3.97
# Élmer Mendoza            3.72
# Émile Zola               3.87
# Name: Rating, Length: 1541, dtype: float64

# %%
from matplotlib import pyplot as plt
d.plot(kind = 'bar', title = 'Best Rating Authors')
# Out:
# <AxesSubplot:title={'center':'Best Rating Authors'}, xlabel='Authors'>

# %%
d.plot(kind = 'bar', title = 'Best Rating Author')
# Out:
# <AxesSubplot:title={'center':'Best Rating Author'}, xlabel='Authors'>

# %%
m = data5[data5.Rating>4.5]

# %%
m
# Out:
#                            Authors Rating
# 8                     J.K. Rowling   4.73
# 571                 Hiromu Arakawa   4.56
# 574                 Hiromu Arakawa   4.55
# 576                 Hiromu Arakawa   4.52
# 615                   Gary Chapman   4.69
# 2282            Arthur Conan Doyle   4.53
# 3306                      Don Rosa   4.67
# 3729                  J.K. Rowling   4.57
# 3792            Frances J. Roberts   4.57
# 3889                Hayao Miyazaki   4.51
# 4458              Elliott A. Norse   4.59
# 5121                  David Burnie   4.51
# 5433              Malvina G. Vogel   4.51
# 8133                 Stuart McLean   4.56
# 9504               Simon Cleveland   4.58
# 10178          Henry David Thoreau   4.75
# 10413           Richard P. Feynman   4.63
# 12541               R. McL. Wilson    5.0
# 13161              Mary B. Collins   4.86
# 14698               Bill Watterson   4.82
# 19001                  Jane Austen   4.56
# ...

# %%
r=m.groupby(['Authors']).mean()

# %%
r
# Out:
#                                Rating
# Authors
# Anonymous                    4.675000
# Arthur Conan Doyle           4.530000
# Bill Watterson               4.820000
# Charles M. Schulz            4.560000
# Cook's Illustrated Magazine  4.570000
# David Burnie                 4.510000
# Don Rosa                     4.670000
# Edwin Meese III              4.540000
# Elliott A. Norse             4.590000
# Erin Hunter                  4.530000
# Frances J. Roberts           4.570000
# Garth Nix                    4.530000
# Gary Chapman                 4.690000
# George R. R. Martin          4.610000
# Hayao Miyazaki               4.510000
# Henry David Thoreau          4.750000
# Hiromu Arakawa               4.560000
# J.K. Rowling                 4.596667
# Jack London                  4.740000
# Jane Austen                  4.560000
# John Wheeler                 4.770000
# Kenneth McRobbie             4.600000
# Malvina G. Vogel             4.510000
# ...

# %%
r.plot(kind = 'bar')
plt.xticks(rotation = 60)
plt.gcf().set_size_inches(20,10)
